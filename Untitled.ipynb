# %%
from open_linkedin_api.linkedin import Linkedin

# %%
api = Linkedin("geoman970@gmail.com", "Geoman11!")

# %%
api.search_companies("emerson")
# Out:
# [{'name': '', 'url': 'https://www.linkedin.com/company/emerson/'},
#  {'name': '',
#   'url': 'https://www.linkedin.com/company/vertiv-emerson-network-power/'},
#  {'name': '',
#   'url': 'https://www.linkedin.com/company/emerson-automation-solutions/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emerson-college/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emerson-collective/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emerson-group-inc/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emerson-hospital/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emersonsoc/'},
#  {'name': '', 'url': 'https://www.linkedin.com/company/emerson-ecologics/'},
#  {'name': '',
#   'url': 'https://www.linkedin.com/company/emerson-motor-company/'}]
