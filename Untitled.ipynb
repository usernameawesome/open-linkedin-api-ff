# %%
from open_linkedin_api_ff.linkedin import Linkedin

# %%
api = Linkedin("geoman970@gmail.com", "Geoman11!")

# %%
datas = api.search_companies("emerson")
datas
# Out:
# [{'name': 'Emerson', 'url': 'https://www.linkedin.com/company/emerson/'},
#  {'name': 'Emerson Network Power',
#   'url': 'https://www.linkedin.com/company/vertiv-emerson-network-power/'},
#  {'name': "Emerson's Automation Technologies & Solutions",
#   'url': 'https://www.linkedin.com/company/emerson-automation-solutions/'},
#  {'name': 'Emerson College',
#   'url': 'https://www.linkedin.com/company/emerson-college/'},
#  {'name': 'Emerson Collective',
#   'url': 'https://www.linkedin.com/company/emerson-collective/'},
#  {'name': 'Emerson Group',
#   'url': 'https://www.linkedin.com/company/emerson-group-inc/'},
#  {'name': 'Emerson Health',
#   'url': 'https://www.linkedin.com/company/emerson-hospital/'},
#  {'name': 'Emerson College School of Communication',
#   'url': 'https://www.linkedin.com/company/emersonsoc/'},
#  {'name': 'Emerson Ecologics',
#   'url': 'https://www.linkedin.com/company/emerson-ecologics/'},
#  {'name': 'Emerson Motor Company',
# ...
